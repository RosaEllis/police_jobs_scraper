# %% [markdown]
# ## Scraping web sites
#
# Using this tutorial series https://www.youtube.com/watch?v=zXif_9RVadI
#
# This code fetches the data from the url and stores it in a 'response' object

# %%
import requests 
from bs4 import BeautifulSoup
r = requests.get('https://allpolicejobs.co.uk/all#jobs')

# %% [markdown]
# Now that the html from the web page is inside the variable r, which is a response object, I can grab the text from it. The text below prints the first 500 characters:

# %%
print(r.text[0:500])
# Out:
# <!DOCTYPE html>
# <html lang="en">
# 	<head>
# 		<meta charset="utf-8">
# 		<title>AllPoliceJobs</title>
# 		<meta name="description" content="">
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0" />
# 		<meta name="author" content="Triden Elite Ltd." />
# 		<meta name="generator" content="MVCms" />
# 		<link href="/style/bootstrap.min.css" rel="stylesheet" />
# 		<link href="/style/style.css" rel="stylesheet" />
# 		<link href="/style/site-responsive.css" rel="stylesheet" />
# 		<lin

# %% [markdown]
# Next r.text is parsed and put inside a special object called soup. Beautiful Soup is reading the html here and making sense of the structure of it. Html parser is the parser included in the standard Python library.

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %% [raw]
# I want to grab:
# job title
# region
# salary
#
# This is the HTML for one police job:
#
#
#  <div class="filter-result">
# 						<div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# 							<div class="company-left-info pull-left">
# 								<img src="/asset/force/logo/westmidlands.boxed-65x65-255-255-255-0.jpg" alt="West Midlands">
# 							</div>
# 							<div class="desig">
# 								<a href="/jobs/153767"><h3>Customer Service Agent</h3></a>
# 								<h4>West Midlands</h4>
# 							</div>
# 						</div>
# 						<div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# 							<div class="pull-right location">
# 								<p></p>
# 							</div>
# 							<div class="data-job">
# 								<h3>£19,719 - £24,273</h3>
# 								<a class="label job-type job-contract pull-right" href="/jobs/153767">Read more</a>
# 							</div>
# 						</div>
# 					</div>

# %% [markdown]
# The code below is getting all the bits of the results object that have a div with a class called 'filter-result' (because that is the class at the beginning of the HTML for every job). It returns a 'beautiful soup results object'. It counts each bit of html that begins with that class as 'one' in the results object.

# %%
results = soup.find_all('table', attrs={'class':'filter-result'})

# %%
print(results)
# Out:
# [<div class="filter-result featured">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Cumbria" src="/asset/force/logo/cumbria.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/47445"><h3>Police Officer Recruitment</h3></a>
# <h4>Cumbria</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p></p>
# </div>
# <div class="data-job">
# <h3>Â£19,971 - Â£38,382 Per year</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/47445">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result featured">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Metropolitan Police Service" src="/asset/force/logo/met.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/3688"><h3>Police Constable</h3></a>
# <h4>Metropolitan Police Service</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p></p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/3688">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Scotland" src="/asset/force/logo/scotland.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/155239"><h3>Temporary Insight and Evaluation Lead</h3></a>
# <h4>Scotland</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Dalmarnock, Glasgow</p>
# </div>
# <div class="data-job">
# <h3>Â£30,291 - Â£34,575</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/155239">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Bedfordshire" src="/asset/force/logo/bedfordshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/155182"><h3>PS/303/BCH ICT Technical Architect</h3></a>
# <h4>Bedfordshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Headquarters, Kempston, Beds , Headquarters, WGC, Herts , Headquarters, Huntingdon, Cambs</p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/155182">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Bedfordshire" src="/asset/force/logo/bedfordshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/155138"><h3>PS/263/C Occupational Health Technician</h3></a>
# <h4>Bedfordshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Sandy Police House , Headquarters, WGC, Herts</p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/155138">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Bedfordshire" src="/asset/force/logo/bedfordshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/155126"><h3>PS/304/BCH ICT Business Architect</h3></a>
# <h4>Bedfordshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Headquarters, Kempston, Beds , Headquarters, WGC, Herts , Headquarters, Huntingdon, Cambs</p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/155126">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Bedfordshire" src="/asset/force/logo/bedfordshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/155132"><h3>PS/305/BCH ICT Developer Data</h3></a>
# <h4>Bedfordshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Headquarters, Kempston, Beds , Headquarters, WGC, Herts , Headquarters, Huntingdon, Cambs</p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/155132">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="British Transport Police" src="/asset/force/logo/transport.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/155104"><h3>Senior Commercial Manager</h3></a>
# <h4>British Transport Police</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p></p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/155104">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Lancashire" src="/asset/force/logo/lancashire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/155086"><h3>- S002-18 NDORS Police Staff Trainer (LC7)</h3></a>
# <h4>Lancashire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Hutton Headquarters</p>
# </div>
# <div class="data-job">
# <h3>Â£24,273 - Â£27,795</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/155086">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Lancashire" src="/asset/force/logo/lancashire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/155089"><h3>- S137-18 Police Investigation Officer PIP1/SOMU (LC5-6)</h3></a>
# <h4>Lancashire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Preston</p>
# </div>
# <div class="data-job">
# <h3>Â£19,317 - Â£24,273</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/155089">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Greater Manchester" src="/asset/force/logo/manchester.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/155078"><h3>Firearms &amp; Explosives Licensing Manager (Grade H)- Temporary - 1732362, - Ref:1732362</h3></a>
# <h4>Greater Manchester</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Other</p>
# </div>
# <div class="data-job">
# <h3>Â£30,180 - Â£31,938 per.annum.</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/155078">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Merseyside" src="/asset/force/logo/merseyside.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/155082"><h3>Transport Services Driver, Vehicle Fleet Management</h3></a>
# <h4>Merseyside</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p></p>
# </div>
# <div class="data-job">
# <h3>Grade B Â£18,123 to Â£19,317</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/155082">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Cheshire" src="/asset/force/logo/cheshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/155054"><h3>Police Staff: Witness Care Team Leader - Crewe</h3></a>
# <h4>Cheshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Crewe</p>
# </div>
# <div class="data-job">
# <h3>Â£22,221 - Â£24,273</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/155054">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Cheshire" src="/asset/force/logo/cheshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/155052"><h3>Police Staff - POLIT Intelligence Officer - Criminal Justice Centre</h3></a>
# <h4>Cheshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p></p>
# </div>
# <div class="data-job">
# <h3>Scale 6</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/155052">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="West Mercia" src="/asset/force/logo/westmercia.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/154975"><h3>LO 1370 - Driving Skills Trainer - Hindlip, Worcestershire</h3></a>
# <h4>West Mercia</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p></p>
# </div>
# <div class="data-job">
# <h3>Â£30,180 - Â£32,259</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/154975">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="West Midlands" src="/asset/force/logo/westmidlands.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/154983"><h3>Project Officer (Construction)</h3></a>
# <h4>West Midlands</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p></p>
# </div>
# <div class="data-job">
# <h3>Â£27,795 - Â£38,925</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/154983">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Warwickshire" src="/asset/force/logo/warwickshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/154953"><h3>LO 1370 - Driving Skills Trainer - Hindlip, Worcestershire</h3></a>
# <h4>Warwickshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p></p>
# </div>
# <div class="data-job">
# <h3>Â£30,180 - Â£32,259</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/154953">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Northamptonshire" src="/asset/force/logo/northamptonshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/154912"><h3>Police Staff: Solutions Architect - FTC - HQ</h3></a>
# <h4>Northamptonshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Force Headquarters</p>
# </div>
# <div class="data-job">
# <h3>Â£39,648.00 - Â£42624.00</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/154912">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Northamptonshire" src="/asset/force/logo/northamptonshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/154909"><h3>Police Staff: Deputy Facilities Manager - Wootton Hall</h3></a>
# <h4>Northamptonshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>TBC on Appointment</p>
# </div>
# <div class="data-job">
# <h3>Â£28,653.00 - Â£31374.00</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/154909">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Lincolnshire" src="/asset/force/logo/lincolnshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/154885"><h3>OPCC Communications Officer (Ref- O18/01)</h3></a>
# <h4>Lincolnshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p></p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/154885">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Lincolnshire" src="/asset/force/logo/lincolnshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/154887"><h3>OPCC Service Delivery Manager (Ref O18/02)</h3></a>
# <h4>Lincolnshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p></p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/154887">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Leicestershire" src="/asset/force/logo/leicestershire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/154877"><h3>Dedicated Neighbourhood Support Volunteer</h3></a>
# <h4>Leicestershire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Forcewide</p>
# </div>
# <div class="data-job">
# <h3>N/A - N/A</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/154877">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Leicestershire" src="/asset/force/logo/leicestershire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/154863"><h3>Vehicle Cleaner &amp; Inventory Volunteer (Cotton Lane &amp; Glossop)</h3></a>
# <h4>Leicestershire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Derby</p>
# </div>
# <div class="data-job">
# <h3>N/A - N/A</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/154863">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Leicestershire" src="/asset/force/logo/leicestershire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/154866"><h3>FIB Secretary</h3></a>
# <h4>Leicestershire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Force Headquarters</p>
# </div>
# <div class="data-job">
# <h3>Â£19,521 - Â£21,618</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/154866">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Derbyshire" src="/asset/force/logo/derbyshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/154853"><h3>Vehicle Cleaner &amp; Inventory Volunteer (Cotton Lane &amp; Glossop)</h3></a>
# <h4>Derbyshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Derby</p>
# </div>
# <div class="data-job">
# <h3>N/A - N/A</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/154853">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Derbyshire" src="/asset/force/logo/derbyshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/154857"><h3>FIB Secretary</h3></a>
# <h4>Derbyshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Force Headquarters</p>
# </div>
# <div class="data-job">
# <h3>Â£19,521 - Â£21,618</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/154857">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Derbyshire" src="/asset/force/logo/derbyshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/154847"><h3>Dedicated Neighbourhood Support Volunteer</h3></a>
# <h4>Derbyshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Forcewide</p>
# </div>
# <div class="data-job">
# <h3>N/A - N/A</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/154847">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Devon &amp; Cornwall" src="/asset/force/logo/devoncornwall.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/154826"><h3>Modern Slavery Insight Researcher (Fixed Term Contract until March 2019)</h3></a>
# <h4>Devon &amp; Cornwall</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Exmouth, Devon</p>
# </div>
# <div class="data-job">
# <h3>The commencing salary will be within Grade 4 starting at Â£19,719 rising by yearly increments to a maximum of Â£21,837</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/154826">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Sussex" src="/asset/force/logo/sussex.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/154766"><h3>Charity Manager</h3></a>
# <h4>Sussex</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Lewes</p>
# </div>
# <div class="data-job">
# <h3>Â£37,563 - Â£41,502</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/154766">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Sussex" src="/asset/force/logo/sussex.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/154749"><h3>Force Research Bureau Operator</h3></a>
# <h4>Sussex</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Headquarters</p>
# </div>
# <div class="data-job">
# <h3>Â£20,874 - Â£22,671</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/154749">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Sussex" src="/asset/force/logo/sussex.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/154754"><h3>Communications Manager</h3></a>
# <h4>Sussex</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Headquarters</p>
# </div>
# <div class="data-job">
# <h3>Â£26,535 - Â£29,307</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/154754">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Hertfordshire" src="/asset/force/logo/hertfordshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/154698"><h3>PS/305/BCH ICT Developer Data</h3></a>
# <h4>Hertfordshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Headquarters, Kempston, Beds , Headquarters, WGC, Herts , Headquarters, Huntingdon, Cambs</p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/154698">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Hertfordshire" src="/asset/force/logo/hertfordshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/154686"><h3>PS/263/C Occupational Health Technician</h3></a>
# <h4>Hertfordshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Sandy Police House , Headquarters, WGC, Herts</p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/154686">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Hertfordshire" src="/asset/force/logo/hertfordshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/154687"><h3>PS/304/BCH ICT Business Architect</h3></a>
# <h4>Hertfordshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Headquarters, Kempston, Beds , Headquarters, WGC, Herts , Headquarters, Huntingdon, Cambs</p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/154687">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Hertfordshire" src="/asset/force/logo/hertfordshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/154681"><h3>PS/303/BCH ICT Technical Architect</h3></a>
# <h4>Hertfordshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Headquarters, Kempston, Beds , Headquarters, WGC, Herts , Headquarters, Huntingdon, Cambs</p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/154681">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Cambridgeshire" src="/asset/force/logo/cambridge.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/154662"><h3>PS/305/BCH ICT Developer Data</h3></a>
# <h4>Cambridgeshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Headquarters, Kempston, Beds , Headquarters, WGC, Herts , Headquarters, Huntingdon, Cambs</p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/154662">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Cambridgeshire" src="/asset/force/logo/cambridge.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/154665"><h3>PS/263/C Occupational Health Technician</h3></a>
# <h4>Cambridgeshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Sandy Police House , Headquarters, WGC, Herts</p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/154665">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Cambridgeshire" src="/asset/force/logo/cambridge.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/154668"><h3>PS/304/BCH ICT Business Architect</h3></a>
# <h4>Cambridgeshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Headquarters, Kempston, Beds , Headquarters, WGC, Herts , Headquarters, Huntingdon, Cambs</p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/154668">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Cambridgeshire" src="/asset/force/logo/cambridge.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/154661"><h3>PS/303/BCH ICT Technical Architect</h3></a>
# <h4>Cambridgeshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Headquarters, Kempston, Beds , Headquarters, WGC, Herts , Headquarters, Huntingdon, Cambs</p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/154661">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Durham" src="/asset/force/logo/durham.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/154635"><h3>Information Management Improvement Manager â Business Innovation &amp; Development Command</h3></a>
# <h4>Durham</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p></p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/154635">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Scotland" src="/asset/force/logo/scotland.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/154014"><h3>Corporate Communications Executive Lead</h3></a>
# <h4>Scotland</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Scottish Police College, Tulliallan</p>
# </div>
# <div class="data-job">
# <h3>Â£34,575 - Â£39,426</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/154014">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="North Wales Police - Heddlu Gogledd Cymru" src="/asset/force/logo/northwales.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/153882"><h3>Building Services Engineer</h3></a>
# <h4>North Wales Police - Heddlu Gogledd Cymru</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p></p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/153882">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="North Wales Police - Heddlu Gogledd Cymru" src="/asset/force/logo/northwales.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/153883"><h3>Custody Nurse</h3></a>
# <h4>North Wales Police - Heddlu Gogledd Cymru</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p></p>
# </div>
# <div class="data-job">
# <h3>SO2 (Â£30,180 - Â£31,935 per annum, pro rata)</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/153883">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="North Wales Police - Heddlu Gogledd Cymru" src="/asset/force/logo/northwales.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/153884"><h3>Head of Crime and Intelligence Analysis</h3></a>
# <h4>North Wales Police - Heddlu Gogledd Cymru</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p></p>
# </div>
# <div class="data-job">
# <h3>POD (Â£42,489 - Â£45,435 per annum)</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/153884">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="North Wales Police - Heddlu Gogledd Cymru" src="/asset/force/logo/northwales.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/153885"><h3>Force Trainer - Current and Future Vacancies</h3></a>
# <h4>North Wales Police - Heddlu Gogledd Cymru</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p></p>
# </div>
# <div class="data-job">
# <h3>Unqualified - 6 (Â£24,813 - Â£26,535 per annum)</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/153885">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="West Yorkshire" src="/asset/force/logo/westyorkshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/153807"><h3>XC905 Source Handler</h3></a>
# <h4>West Yorkshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Wakefield</p>
# </div>
# <div class="data-job">
# <h3>Â£25,062 - Â£26,802 per annum</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/153807">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="North Yorkshire" src="/asset/force/logo/northyorkshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/153788"><h3>Holmes Indexer - June 2018</h3></a>
# <h4>North Yorkshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Harrogate</p>
# </div>
# <div class="data-job">
# <h3>Â£22,221 - Â£24,273</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/153788">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="West Midlands" src="/asset/force/logo/westmidlands.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/153767"><h3>Customer Service Agent</h3></a>
# <h4>West Midlands</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p></p>
# </div>
# <div class="data-job">
# <h3>Â£19,719 - Â£24,273</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/153767">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="West Midlands" src="/asset/force/logo/westmidlands.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/153768"><h3>Intelligence Learning &amp; Development Officer</h3></a>
# <h4>West Midlands</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p></p>
# </div>
# <div class="data-job">
# <h3>Â£27,795 - Â£33,933</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/153768">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="West Midlands" src="/asset/force/logo/westmidlands.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/153769"><h3>Digital Forensic Officer</h3></a>
# <h4>West Midlands</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p></p>
# </div>
# <div class="data-job">
# <h3>Â£27,795 - Â£33,933</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/153769">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="West Midlands" src="/asset/force/logo/westmidlands.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/153774"><h3>Graduate Resourcing Assistant</h3></a>
# <h4>West Midlands</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p></p>
# </div>
# <div class="data-job">
# <h3>Â£16,923 - Â£19,317</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/153774">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="West Mercia" src="/asset/force/logo/westmercia.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/153756"><h3>LO 1366 - Investigative Skills Trainer - Hindlip, Worcestershire</h3></a>
# <h4>West Mercia</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p></p>
# </div>
# <div class="data-job">
# <h3>Â£30,483 - Â£32,259</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/153756">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="West Mercia" src="/asset/force/logo/westmercia.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/153757"><h3>LO 1364 - Secretary - Nuneaton, Warwickshire</h3></a>
# <h4>West Mercia</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p></p>
# </div>
# <div class="data-job">
# <h3>Â£19,719 - Â£21,837</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/153757">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Warwickshire" src="/asset/force/logo/warwickshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/153735"><h3>LO 1366 - Investigative Skills Trainer - Hindlip, Worcestershire</h3></a>
# <h4>Warwickshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p></p>
# </div>
# <div class="data-job">
# <h3>Â£30,483 - Â£32,259</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/153735">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Warwickshire" src="/asset/force/logo/warwickshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/153743"><h3>LO 1364 - Secretary - Nuneaton, Warwickshire</h3></a>
# <h4>Warwickshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p></p>
# </div>
# <div class="data-job">
# <h3>Â£19,719 - Â£21,837</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/153743">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Leicestershire" src="/asset/force/logo/leicestershire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/153667"><h3>Home Security Visit Volunteer</h3></a>
# <h4>Leicestershire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Other</p>
# </div>
# <div class="data-job">
# <h3>N/A - N/A</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/153667">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Leicestershire" src="/asset/force/logo/leicestershire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/153670"><h3>Police Staff Investigator</h3></a>
# <h4>Leicestershire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Tigers Road</p>
# </div>
# <div class="data-job">
# <h3>Â£27,519 - Â£29,307</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/153670">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Derbyshire" src="/asset/force/logo/derbyshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/153646"><h3>Home Security Visit Volunteer</h3></a>
# <h4>Derbyshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Other</p>
# </div>
# <div class="data-job">
# <h3>N/A - N/A</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/153646">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Derbyshire" src="/asset/force/logo/derbyshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/153653"><h3>Police Staff Investigator</h3></a>
# <h4>Derbyshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Tigers Road</p>
# </div>
# <div class="data-job">
# <h3>Â£27,519 - Â£29,307</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/153653">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Leicestershire" src="/asset/force/logo/leicestershire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/153657"><h3>Home Security Support Volunteer</h3></a>
# <h4>Leicestershire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Other</p>
# </div>
# <div class="data-job">
# <h3>N/A - N/A</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/153657">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Dorset" src="/asset/force/logo/dorset.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/153627"><h3>Specialist Heavy Goods Vehicle (HGV) Driver/ Semi-skilled Vehicle Technician and Storekeeper</h3></a>
# <h4>Dorset</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p></p>
# </div>
# <div class="data-job">
# <h3>The commencing salary will be within</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/153627">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Derbyshire" src="/asset/force/logo/derbyshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/153641"><h3>Home Security Support Volunteer</h3></a>
# <h4>Derbyshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Other</p>
# </div>
# <div class="data-job">
# <h3>N/A - N/A</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/153641">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Thames Valley" src="/asset/force/logo/thamesvalley.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/153581"><h3>Procurement Manager</h3></a>
# <h4>Thames Valley</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Kidlington</p>
# </div>
# <div class="data-job">
# <h3>Band 4J circa Â£40,067 per annum. Progression based on performance. Plus benefits</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/153581">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Surrey" src="/asset/force/logo/surrey.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/153522"><h3>Accredited Financial Investigator</h3></a>
# <h4>Surrey</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Force Wide</p>
# </div>
# <div class="data-job">
# <h3>Â£32,254</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/153522">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Surrey" src="/asset/force/logo/surrey.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/153517"><h3>Shared Business Services Assistant (HR, Recruitment and Learning&amp;Development)</h3></a>
# <h4>Surrey</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Headquarters, Guildford</p>
# </div>
# <div class="data-job">
# <h3>Â£20,084</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/153517">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Suffolk" src="/asset/force/logo/suffolk.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/153496"><h3>Detention Officer</h3></a>
# <h4>Suffolk</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p></p>
# </div>
# <div class="data-job">
# <h3>Band D: Â£22,902 - Â£25,914 per annum/pro rata, plus 20% shift allowance and weekend enhancements</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/153496">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Suffolk" src="/asset/force/logo/suffolk.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/153498"><h3>ICT Project Manager</h3></a>
# <h4>Suffolk</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p></p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/153498">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Hertfordshire" src="/asset/force/logo/hertfordshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/153484"><h3>PS/281/B ICT Client Development Engineer</h3></a>
# <h4>Hertfordshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Headquarters, Kempston, Beds , Headquarters, WGC, Herts , Headquarters, Huntingdon, Cambs</p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/153484">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Hertfordshire" src="/asset/force/logo/hertfordshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/153486"><h3>ERSOU ROCU - Confidential Unit Intelligence Analyst</h3></a>
# <h4>Hertfordshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Other</p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/153486">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Hertfordshire" src="/asset/force/logo/hertfordshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/153488"><h3>PS/298/BCH HR Service Centre Assistant (Projected Vacancies)</h3></a>
# <h4>Hertfordshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Stevenage</p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/153488">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Hertfordshire" src="/asset/force/logo/hertfordshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/153489"><h3>PS/841/H Police Staff Driving Instructor</h3></a>
# <h4>Hertfordshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Headquarters, WGC, Herts</p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/153489">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Suffolk" src="/asset/force/logo/suffolk.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/153490"><h3>Admin Clerk</h3></a>
# <h4>Suffolk</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p></p>
# </div>
# <div class="data-job">
# <h3>Band B: Â£17,721 - Â£19,317 per annum pro rata</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/153490">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Hertfordshire" src="/asset/force/logo/hertfordshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/153471"><h3>PS/834/H Insurance Officer</h3></a>
# <h4>Hertfordshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Headquarters, WGC, Herts</p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/153471">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Hertfordshire" src="/asset/force/logo/hertfordshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/153472"><h3>PS/293/BCH ICT PMO Support Officer</h3></a>
# <h4>Hertfordshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# ...
# </div>
# <div class="desig">
# <a href="/jobs/20219"><h3>DBA Technician (Oracle)</h3></a>
# <h4>Suffolk</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p></p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/20219">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Cheshire" src="/asset/force/logo/cheshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/19569"><h3>Volunteer - Victims Panel Member - Force HQ</h3></a>
# <h4>Cheshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Police Headquarters</p>
# </div>
# <div class="data-job">
# <h3>Volunteer</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/19569">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Cumbria" src="/asset/force/logo/cumbria.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/19473"><h3>Special Constables and Police Support Volunteers Vacancies</h3></a>
# <h4>Cumbria</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p></p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/19473">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="South Yorkshire" src="/asset/force/logo/southyorkshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/18133"><h3>- Humberside Police - Transferee Vacancies - Police Constables, Sergeants and Inspectors</h3></a>
# <h4>South Yorkshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Force Wide</p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/18133">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="South Yorkshire" src="/asset/force/logo/southyorkshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/18135"><h3>- HP Police Service Volunteers</h3></a>
# <h4>South Yorkshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Force Wide</p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/18135">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Humberside" src="/asset/force/logo/humberside.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/16714"><h3>- HP Police Service Volunteers</h3></a>
# <h4>Humberside</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Force Wide</p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/16714">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Humberside" src="/asset/force/logo/humberside.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/16718"><h3>- Humberside Police - Transferee Vacancies - Police Constables, Sergeants and Inspectors</h3></a>
# <h4>Humberside</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Force Wide</p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/16718">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Staffordshire" src="/asset/force/logo/staffordshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/11056"><h3>Police Now: Graduate Leadership Programme</h3></a>
# <h4>Staffordshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p></p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/11056">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Sussex" src="/asset/force/logo/sussex.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/8755"><h3>Detective Constable Transferee - Investigations</h3></a>
# <h4>Sussex</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Multiple Locations</p>
# </div>
# <div class="data-job">
# <h3>National Payscale</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/8755">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Surrey" src="/asset/force/logo/surrey.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/8628"><h3>Transferee- Detective Constable</h3></a>
# <h4>Surrey</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Forcewide</p>
# </div>
# <div class="data-job">
# <h3>National Pay Scale</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/8628">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Surrey" src="/asset/force/logo/surrey.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/8631"><h3>Transferee - Detective Sergeant</h3></a>
# <h4>Surrey</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Forcewide</p>
# </div>
# <div class="data-job">
# <h3>National Pay Scale</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/8631">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Surrey" src="/asset/force/logo/surrey.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/8639"><h3>Contact Handler</h3></a>
# <h4>Surrey</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Headquarters, Guildford</p>
# </div>
# <div class="data-job">
# <h3>Â£21,954 plus Â£4,222 unsocial hours allowance</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/8639">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Lincolnshire" src="/asset/force/logo/lincolnshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/5868"><h3>Cadet leader volunteer (Ref: 38)</h3></a>
# <h4>Lincolnshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p></p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/5868">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Lincolnshire" src="/asset/force/logo/lincolnshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/5851"><h3>Apply now to become a special constable</h3></a>
# <h4>Lincolnshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p></p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/5851">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Lincolnshire" src="/asset/force/logo/lincolnshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/5859"><h3>Transferee opportunities</h3></a>
# <h4>Lincolnshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p></p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/5859">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Lincolnshire" src="/asset/force/logo/lincolnshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/5860"><h3>Crime prevention pack volunteer (Ref: 46)</h3></a>
# <h4>Lincolnshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p></p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/5860">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Lincolnshire" src="/asset/force/logo/lincolnshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/5861"><h3>REVIVE Volunteer (Ref: 74)</h3></a>
# <h4>Lincolnshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p></p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/5861">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Lincolnshire" src="/asset/force/logo/lincolnshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/5862"><h3>Community Priorities Volunteer (Ref: 4)</h3></a>
# <h4>Lincolnshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p></p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/5862">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Lincolnshire" src="/asset/force/logo/lincolnshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/5864"><h3>Apply now to become a police support volunteer</h3></a>
# <h4>Lincolnshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p></p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/5864">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Leicestershire" src="/asset/force/logo/leicestershire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/5515"><h3>Special Constabulary - Leicestershire</h3></a>
# <h4>Leicestershire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Force Headquarters</p>
# </div>
# <div class="data-job">
# <h3>N/A - N/A</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/5515">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Metropolitan Police Service" src="/asset/force/logo/met.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/3682"><h3>Volunteer Police Cadet Leader</h3></a>
# <h4>Metropolitan Police Service</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Various locations</p>
# </div>
# <div class="data-job">
# <h3>Unbanded</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/3682">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Metropolitan Police Service" src="/asset/force/logo/met.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/3691"><h3>Designated Detention Officer (DDO)</h3></a>
# <h4>Metropolitan Police Service</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Across London</p>
# </div>
# <div class="data-job">
# <h3>Band E</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/3691">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Metropolitan Police Service" src="/asset/force/logo/met.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/3672"><h3>Community Assessor</h3></a>
# <h4>Metropolitan Police Service</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Refer to advert</p>
# </div>
# <div class="data-job">
# <h3>Casual</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/3672">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Metropolitan Police Service" src="/asset/force/logo/met.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/3680"><h3>Special Constable</h3></a>
# <h4>Metropolitan Police Service</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p></p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/3680">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Bedfordshire" src="/asset/force/logo/bedfordshire.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/3548"><h3>ERSOU - Support Services Administrator</h3></a>
# <h4>Bedfordshire</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Other</p>
# </div>
# <div class="data-job">
# <h3></h3>
# <a class="label job-type job-contract pull-right" href="/jobs/3548">Read more</a>
# </div>
# </div>
# </div>, <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="City of London" src="/asset/force/logo/london.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/2885"><h3>Transferee and Rejoiner Uniform and Detective Constables</h3></a>
# <h4>City of London</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Various</p>
# </div>
# <div class="data-job">
# <h3>National rates</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/2885">Read more</a>
# </div>
# </div>
# </div>]

# %% [markdown]
# The beautiful soup results object acts like a python list, which means I can check the length of it with len. The result is 536 and there are 536 jobs on the website!

# %%
len(results)
# Out:
# 536

# %%
results[0:3]
# Out:
# [<div class="filter-result featured">
#  <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
#  <div class="company-left-info pull-left">
#  <img alt="Cumbria" src="/asset/force/logo/cumbria.boxed-65x65-255-255-255-0.jpg"/>
#  </div>
#  <div class="desig">
#  <a href="/jobs/47445"><h3>Police Officer Recruitment</h3></a>
#  <h4>Cumbria</h4>
#  </div>
#  </div>
#  <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
#  <div class="pull-right location">
#  <p></p>
#  </div>
#  <div class="data-job">
#  <h3>Â£19,971 - Â£38,382 Per year</h3>
#  <a class="label job-type job-contract pull-right" href="/jobs/47445">Read more</a>
#  </div>
#  </div>
#  </div>, <div class="filter-result featured">
#  <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
#  <div class="company-left-info pull-left">
#  <img alt="Metropolitan Police Service" src="/asset/force/logo/met.boxed-65x65-255-255-255-0.jpg"/>
#  </div>
#  <div class="desig">
#  <a href="/jobs/3688"><h3>Police Constable</h3></a>
#  <h4>Metropolitan Police Service</h4>
#  </div>
#  </div>
#  <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
#  <div class="pull-right location">
#  <p></p>
#  </div>
#  <div class="data-job">
#  <h3></h3>
#  <a class="label job-type job-contract pull-right" href="/jobs/3688">Read more</a>
#  </div>
#  </div>
#  </div>, <div class="filter-result">
#  <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
#  <div class="company-left-info pull-left">
#  <img alt="Scotland" src="/asset/force/logo/scotland.boxed-65x65-255-255-255-0.jpg"/>
#  </div>
#  <div class="desig">
#  <a href="/jobs/155239"><h3>Temporary Insight and Evaluation Lead</h3></a>
#  <h4>Scotland</h4>
#  </div>
#  </div>
#  <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
#  <div class="pull-right location">
#  <p>Dalmarnock, Glasgow</p>
#  </div>
#  <div class="data-job">
#  <h3>Â£30,291 - Â£34,575</h3>
#  <a class="label job-type job-contract pull-right" href="/jobs/155239">Read more</a>
#  </div>
#  </div>
#  </div>]

# %% [markdown]
# Next check that the last job on the page is the same as the last one I've scraped

# %%
results[-1]
# Out:
# <div class="filter-result">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="City of London" src="/asset/force/logo/london.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/2885"><h3>Transferee and Rejoiner Uniform and Detective Constables</h3></a>
# <h4>City of London</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p>Various</p>
# </div>
# <div class="data-job">
# <h3>National rates</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/2885">Read more</a>
# </div>
# </div>
# </div>

# %% [markdown]
# Below I am putting the first job inside a variable so that I can work out the exact code with just one job.

# %%
first_result = results[0]
first_result
# Out:
# <div class="filter-result featured">
# <div class="col-lg-6 col-md-7 col-sm-9 col-xs-12 pull-left">
# <div class="company-left-info pull-left">
# <img alt="Cumbria" src="/asset/force/logo/cumbria.boxed-65x65-255-255-255-0.jpg"/>
# </div>
# <div class="desig">
# <a href="/jobs/47445"><h3>Police Officer Recruitment</h3></a>
# <h4>Cumbria</h4>
# </div>
# </div>
# <div class="col-lg-6 col-md-5 col-sm-8 col-xs-12 pull-right">
# <div class="pull-right location">
# <p></p>
# </div>
# <div class="data-job">
# <h3>Â£19,971 - Â£38,382 Per year</h3>
# <a class="label job-type job-contract pull-right" href="/jobs/47445">Read more</a>
# </div>
# </div>
# </div>

# %% [markdown]
# The variable called first_result is a special kind of beautiful soup object called a tag, that has methods and attributes we can use.

# %% [markdown]
# The code below is searching first_result for the first instance of the h3 tag, and returns it as a beautiful soup tag object.

# %% [markdown]
# The code below is asking for just the text:

# %%
first_result.find('h3').text
# Out:
# 'Police Officer Recruitment'

# %%
first_result.find('h4').text
# Out:
# 'Cumbria'

# %%
first_result.find_all('h3')[1].text[1:]
# Out:
# '£19,971 - Â£38,382 Per year'

# %%
first_result.find('a')['href']
# Out:
# '/jobs/47445'

# %% [markdown]
# So now I have worked out how to get the job title, region, salary and link, I need to do a loop...

# %%
records = []
for result in results:
    job = result.find('h3').text
    region = result.find('h4').text
    salary = result.find_all('h3')[1].text[1:]
    link = result.find('a')['href']
    records.append((job, region, salary, link))

# %%
records[0:3]
# Out:
# [('Police Officer Recruitment',
#   'Cumbria',
#   '£19,971 - Â£38,382 Per year',
#   '/jobs/47445'),
#  ('Police Constable', 'Metropolitan Police Service', '', '/jobs/3688'),
#  ('Temporary Insight and Evaluation Lead',
#   'Scotland',
#   '£30,291 - Â£34,575',
#   '/jobs/155239')]

# %%
len(records)
# Out:
# 536

# %%
import pandas as pd
df = pd.DataFrame(records, columns=['job','region','salary','link'])

# %%
df.head()
# Out:
#                                        job                       region  \
# 0               Police Officer Recruitment                      Cumbria
# 1                         Police Constable  Metropolitan Police Service
# 2    Temporary Insight and Evaluation Lead                     Scotland
# 3       PS/303/BCH ICT Technical Architect                 Bedfordshire
# 4  PS/263/C Occupational Health Technician                 Bedfordshire
#
#                         salary          link
# 0  £19,971 - Â£38,382 Per year   /jobs/47445
# 1                                 /jobs/3688
# 2           £30,291 - Â£34,575  /jobs/155239
# 3                               /jobs/155182
# 4                               /jobs/155138

# %%
df.to_csv('police_jobs.csv')
